# %% [markdown]
# # Edibility of Mushrooms #
# ---
# **Research Question:** What physical characteristics found in mushrooms can help us diffirientiate if it is edible or not?
#
# The original data set can be found [here](https://www.kaggle.com/uciml/mushroom-classification)

# %% [markdown]
# # Introduction #
# ---
# After conducting our own individual Exploratory Data Analysis (EDA) on the data, we found several characteristics that can help us identify the edibility of said mushroom. Most of our data analysis was achieved by plotting the count of specific features, while differentiating the class of mushroom (edible or poisonous). From here we were able to find specific ratios for each characteristic, and this in term helped us to tell which traits belonged mostly to edible mushrooms, which ones belonged to poisonous, and which ones were common between both classes. With this technique we have managed to identify what we believe are some of the most important factors that can help us distinguish between possible death, and a delicious dinner.

# %% [markdown]
# ### Importing Modules ###

# %%
# !pip install pandas seaborn numpy matplotlib # Uncomment if modules are not found
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from scripts import project_functions

# %% [markdown]
# ### Load and Preprocess Data ###

# %%
df = project_functions.load_and_process_data("../../data/raw/mushrooms.csv")
ratioDict = project_functions.show_edibility_ratio(df)
df
# Out:
#           Class Cap Shape Cap Surface Cap Color  Bruises     Odor  \
# 0        edible      flat     fibrous     brown     True     none
# 1        edible      flat     fibrous       red     True     none
# 2        edible      flat       scaly     brown     True     none
# 3        edible      flat     fibrous       red     True     none
# 4        edible      flat     fibrous      gray     True     none
# ...         ...       ...         ...       ...      ...      ...
# 8119  poisonous      flat     fibrous      gray    False     foul
# 8120  poisonous      flat     fibrous    yellow    False     foul
# 8121  poisonous      flat     fibrous    yellow    False     foul
# 8122  poisonous    convex       scaly      gray    False     foul
# 8123  poisonous    convex      smooth     brown     True  pungent
#
#      Gill Attachment Gill Spacing Gill Size Gill Color  ...  \
# 0               free        close     broad      brown  ...
# ...

# %% [markdown]
# # Segmenting the Data #
# ---
# Since there are so many distinct characteristics to a mushroom we have opted to separate these into different categories for an easier and more organized analysis. These include: cap, gill, stalk, viel, ring, life and miscellaneous traits.

# %% [markdown]
# ### How to Read the Data ###
# ---
# We have two distinct types of bargraphs below, the first one displays the *count* of edible and poisonous mushrooms with a certain characteristic (these are the red and blue graphs), directly below them you can find the associated "Edibility Ratio" bargraphs in which we calculate the ratio of the amount of edible mushrooms compared to the total amount of mushrooms with that specific trait, the formula for the ratio is:
#
# $\frac{e}{e+p}$
#
# Where *e* is the number of *edible* mushrooms with a specific trait, and *p* is the number of *poisonous* mushrooms with that same trait.
#
# Overall when it comes to the Edibility Ratio bargraph the closer the value is to 1, the better that characteristic serves as an indicator for the mushroom to be edible. The closer to 0, the better it indicates that the mushroom is poisonous.

# %% [markdown]
# ### Important Note ###
# ---
# Some figures might appear very small and unreadable at first, you can *double click* them in order to view an enlarged, more clear version.

# %% [markdown]
# # Analysis of Data #
# ---

# %% [markdown]
# ### Cap Related Traits ###
# ---
# Overall when it comes to the cap of the mushroom there is really not enough prevelant distinctions to determine if a mushroom is poisonous or not. Many of the features are shared between both edible and poisonous mushrooms, for example: a convex cap shape, a scaly surface, or a brown or gray mushroom cap. Nontheless, there are some characteristics — like a knobbed cap shape and red, yellow or buff colored caps — that seem to be a lot more common between poisonous mushrooms. There is one trait, grooves in the cap surface, that are distinclty traits of a poisonous mushroom, but these are very rare.

# %%
project_functions.show_cap_related_features(df, ratioDict)

# %% [markdown]
# ### Gill Related Traits ###
# ---
# When it comes to the gill of the mushroom there are actually a couple traits than can help us distingush between an edible or poisonous mushroom. The most prevelant one is the gill color, as it appears that green and buff colored gill's are really good indicators for the toxicity of a mushroom. Similarly, if a mushroom has a narrow gill it would be better to assume it as toxic as there is more than double the amount of poisonous mushrooms with narrow gills than edible. As for the other characteristics, if a mushroom has crowded gill spacing or atached gills it is likely for it to be edible, but not definite.

# %%
project_functions.show_gill_related_features(df, ratioDict)

# %% [markdown]
# ### Stalk Related Traits ###
# ---
# For the stalk of the mushroom there seems to be a relation with the roughness of the stalk both above and below the ring as well as with the color of the stalk. Overall mushrooms with a silky stalk colored either cinammon, yellow, or buff (both above and below the ring) appear to be overall poisonous. In this case the better indicator is the color, as if the stalk happens to be of one of those colors it is most definitley poisonous. It important to mention thataltough they are good indicators, these traits tend to be more rare as they form a very small percentage out of the entire sample.
#
# Another notable characteristic is that mushrooms with a rooted stalk are very likely to be edible, as well as mushrooms with gray or red stalks (both above and below ring).

# %%
project_functions.show_stalk_related_features(df, ratioDict)

# %% [markdown]
# ### Veil Related Traits ###
# ---
# In the case of the veil, mushrooms with an orange or brown veil seem to be edible, altough they are quite rare. When it comes to a partial veil both poisonous and edible mushrooms share this characteristic.

# %%
project_functions.show_veil_related_features(df, ratioDict)

# %% [markdown]
# ### Ring Related Traits ###
# ---
# As for the ring of the mushrooms, it appears that mushrooms with no rings, or large rings are poisonous. This appears to be a good indicator for the toxicity. As for the edibility of mushrooms if a mushroom has a flaring ring type is likely for it to be edible, and similarly (but not always) having 2 rings could suggest an edible mushroom.
#
# The other traits are mostly 'evenly' shared between the two classes of mushroom.

# %%
project_functions.show_ring_related_features(df, ratioDict)

# %% [markdown]
# ### Life Related Traits ###
# ---
# For the population type and habitat of the mushrooms there are some characteristics that allow us to know if the mushroom is edible or not. For example if a mushroom has an abundant or numerous population the mushroom is edible, similiarly if it grows on waste the mushroom will be edible.
#
# As for poisonous mushrooms, it is better to not eat any mushrooms found on paths, urban areas or leaves as the majority of these seem to be poisonous, likewise if a mushroom has 'several' population type is it very likely poisonous.

# %%
project_functions.show_life_related_features(df, ratioDict)

# %% [markdown]
# ### Miscellaneous Traits ###
# ---
# Surprisingly this category has some of the most telling signs for the edibility of a mushroom. When it comes to the odor of the mushrooms, if it smells: spicy, fishy, foul, pungent, musty, or, treosote it will be poisonous. On the otherhand the large majority of mushrooms with no smell are edible.
#
# Another good sign for poisonous mushrooms is the color of the spore print, as any mushrooms with green, or chocolate colored spores prints are highly likely to be poisonous. When it comes to the bruises most edible mushrooms have them while poisounous do not, but this is not always the case so it is not a very good trait to tell them apart.

# %%
project_functions.show_miscellaneous_features(df, ratioDict)

# %% [markdown]
# # Conclusion #
# ---

# %%
important_traits_for_edibility = project_functions.sort_by_influence(ratioDict)
important_traits_for_edibility[important_traits_for_edibility['Edibility']<0.4]
# Out:
#                              Feature  Edibility
# 2                  Knobbed Cap Shape   0.275362
# 5                  Conical Cap Shape   0.000000
# 9                Grooves Cap Surface   0.000000
# 13                  Yellow Cap Color   0.373134
# 15                    Buff Cap Color   0.285714
# 16                    Pink Cap Color   0.388889
# 20                     FAlse Bruises   0.306655
# 23                         Foul Odor   0.000000
# 24                        Spicy Odor   0.000000
# 25                        Fishy Odor   0.000000
# 28                      Pungent Odor   0.000000
# 29                     Creosote Odor   0.000000
# 30                        Musty Odor   0.000000
# 36                  Narrow Gill Size   0.114650
# 37                   Buff Gill Color   0.000000
# 41                   Gray Gill Color   0.329787
# 42              Chocolate Gill Color   0.278689
# 48                  Green Gill Color   0.000000
# 56    Silky Stalk Surface Above Ring   0.060708
# ...

# %% [markdown]
# Overall there are many differnt characteristics to mushrooms and edible and poisonous mushrooms share many of them. Because of this there is no particular formula to guarantee that a mushroom is edible or not, nonetheless there are enough differences for us to create a hypothesis with a high likelyhood of acertion. The following are things one should consider when judging a mushroom (and both of them should be considered):
#
# **1. Edible Mushrooms Could Have These Characteristics:**
#     - Have no particular odor, or smell like anise or almond (big teller).
#     - Have a gray or red rooted stalk (altough these are not very common they are likely edible).
#     - Have orange or brown veil (once again not very common, but very likely edible).
#     - Pendant ring (does not guarantee edibility).
#     - Brown Sprore Print (does not guarantee edibility).
#     - Grows on waste habitat and has an abundant/numerous population. (Edible mushrooms also grow in many other places but so do poisonous ones).
#
#
# **2. Poisonous Mushrooms Could Have These Characteristics:**
#     - Odor, anything that smells bad, spicy, fishy, in general foul (very good teller).
#     - Chocolate, or white spore print colors.
#     - Grow on paths (keep in mind they can grow in many other places, but path mushrooms tend to be poisonous).
#     - A large singular ring, or no ring on the mushroom.
#     - A silky stalk colored either cinammon, yellow, or buff (both above and below the ring).
#     - A buff colored gill (another good indicator as if they have this they are very likeley poisonous).
#
# Keep in mind these are just guidelines, and there is nothing stopping a perfectly edible mushroom to have characterisitcs of a poisonous one or vice versa. Overall these gudilines can help us form a better judgement of the edibility of a mushroom, but it is always better to play it safe if we really don't know.
